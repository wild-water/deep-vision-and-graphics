# %% [markdown]
# # Compact Convolutional Transformers
#
# This week we try to train Vision Transformer-like network for cifar10 images classification.
#
# This task is based on paper [Escaping the Big Data Paradigm with Compact Transformers](https://arxiv.org/pdf/2104.05704.pdf)

# %% [markdown]
# ## CIFAR dataset
#
# You have already met this dataset in seminar 2.
#
# * 60k images of shape 3x32x32
# * 10 different classes: planes, dogs, cats, trucks, etc.
#
# <img src="cifar10.jpg" style="width:80%">

# %%
# when running in colab, un-comment this
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py

# %%
#!L
import numpy as np
import random
from cifar import load_cifar10
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10("cifar_data")

class_names = np.array(['airplane', 'automobile', 'bird', 'cat', 'deer',
                        'dog', 'frog', 'horse', 'ship', 'truck'])

print(X_train.shape,y_train.shape)
# Out:
# (40000, 3, 32, 32) (40000,)

# %%
#!L
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=[12,10])
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(np.transpose(X_train[i],[1,2,0]))
    plt.title(class_names[y_train[i]])

# %% [markdown]
# ## Prepare dataset and loss
#
# The following code is based on homework 1-pt2 and should be familiar to you.

# %%
#!L
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
import tqdm

# %%
#!L
def get_computing_device():
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu')
    return device

device = get_computing_device()
print(f"Our main computing device is '{device}'")
# Out:
# Our main computing device is 'cuda:0'

# %%
#!L
def compute_loss(logits, y_batch):
    return F.cross_entropy(logits, y_batch).mean().cpu()

# %%
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2470, 0.2435, 0.2616))

transform_augment = transforms.Compose([
    transforms.RandomResizedCrop((32,32), scale=(0.9, 1.0), ratio=(0.9, 1.1)),
    transforms.RandomRotation([-5, 5]),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.ColorJitter(0.2, 0.2, 0.2, 0.2),
    transforms.Normalize(means, stds),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

# %%
from torchvision.datasets import CIFAR10
train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)

train_batch_gen = torch.utils.data.DataLoader(train_loader, 
                                              batch_size=50,
                                              shuffle=True,
                                              num_workers=2)
val_loader = CIFAR10("./cifar_data/", train=False, transform=transform_test)

val_batch_gen = torch.utils.data.DataLoader(val_loader, 
                                              batch_size=50,
                                              shuffle=False,
                                              num_workers=2)

# %% [markdown]
# ## Task 1. Multi-head attention
#
# Your turn!

# %% [markdown]
# <img src="https://data-science-blog.com/wp-content/uploads/2022/01/mha_img_original.png" style="width:50%">

# %% [markdown]
# Let's implement MultiHeadAttention for beggining. It's already implemented in pytorch, so we will use `nn.MultiHeadAttention` for testing of your implementation.
#
# As a reminder, (one-head) attention implements a simple formula: $\text{Attention}(Q,K,V) = \text{softmax}(\frac{QK^T}{\sqrt{d_k}})V$, where $d_k$ is size of K

# %%
class CustomMultiHeadSelfAttention(nn.Module):
    def __init__(self, embed_dim, num_heads, dropout=0.0):
        super().__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        assert embed_dim % num_heads == 0, "embed_dim must be divisible by num_heads"

        self.in_proj = nn.Linear(embed_dim, 3*embed_dim)  # don't change the name
        self.out_proj = nn.Linear(embed_dim, embed_dim)  # don't change the name
        
        self.norm_coeff = self.head_dim ** 0.5
        
        self.attention_dropout = nn.Dropout(dropout)
        
    def forward(self, qkv):
        """
        qkv - query, key and value - it should be the same tensor since we implement self-attention
        """
        # YOUR CODE
        # 1. apply self.in_proj to qkv
        # 2. split the result of step 1 on three equal parts of size self.embed_dim: query, key, value
        # 3. compute scaled dot-product attention for different heads in loop. 
        #    i-th head will work on query[:, :, i*head_dim: (i+1)*head_dim], 
        #    key[:, :, i*head_dim: (i+1)*head_dim], value[:, :, i*head_dim: (i+1)*head_dim]
        # 4. apply dropout for each head result
        # 5. concat all results
        # 6. apply self.out_proj to the result of step 5

        qkv = self.in_proj(qkv)
        q = qkv[...,:self.embed_dim]
        k = qkv[...,self.embed_dim:2*self.embed_dim]
        v = qkv[...,2*self.embed_dim:3*self.embed_dim]
        head_results = []
        for i in range(self.num_heads):
            att = torch.matmul(q[..., i*self.head_dim: (i+1)*self.head_dim],
                               torch.transpose(k[..., i*self.head_dim: (i+1)*self.head_dim], -1, -2))
            att /= self.norm_coeff
            att = F.softmax(att, dim=-1)
            head_result = torch.matmul(att,  v[..., i*self.head_dim: (i+1)*self.head_dim])
            head_result = self.attention_dropout(head_result)
            head_results.append(head_result)

        result = torch.cat(head_results, dim=-1)
        result = self.out_proj(result)
        return result

# %% [markdown]
# Let's check that your implementation works like `torch.nn.MultiheadAttention`

# %%
mha = torch.nn.MultiheadAttention(embed_dim=128, num_heads=16, batch_first=True)

# %%
custom_mha = CustomMultiHeadSelfAttention(embed_dim=128, num_heads=16)
custom_mha.in_proj.weight = mha.in_proj_weight
custom_mha.in_proj.bias = mha.in_proj_bias
custom_mha.out_proj.weight = mha.out_proj.weight
custom_mha.out_proj.bias = mha.out_proj.bias

# %%
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

for _ in range(100):
    a = torch.rand((1, 10, 128))
    out1 = mha(a, a, a)[0].cpu().detach().numpy()
    out2 = custom_mha(a).cpu().detach().numpy()
    assert np.allclose(out1, out2, atol=1e-6), f"{out1} {out2}"
    
print ("Congratulations! It works!")
# Out:
# Congratulations! It works!

# %% [markdown]
# ## Task 2: Step-wise learning rate with warm-up
#
# Your task is to implement class that works as `torch.optim.lr_scheduler.StepLR` but supports warm-up.
#
# First of all, examine the docstring and implementation of `StepLR` scheduler:

# %%
torch.optim.lr_scheduler.StepLR?

# %% [markdown]
# Then implement `get_lr()` method. It should work as following:
# 1. If `self.last_epoch` is in `[0, self.warmup_epochs)`, then scheduler is in warm-up mode and learning rate should lineary increase during epochs from `self.warmup_lr_init` to `self.base_lrs` (which is the original learning rate of optimizer)
# 2. If `self.last_epoch` is equal to `self.warmup_epochs`, then just return `self.base_lrs`.
# 3. If `self.last_epoch - self.warmup_epochs` is not divisible by `self.step_size` then just return the previous learning rate which is available through `[group['lr'] for group in self.optimizer.param_groups]`
# 4. If `self.last_epoch - self.warmup_epochs` is divisible by `self.step_size` and the current learning rate multiplied by `self.gamma` is not less then self.min_lr, then multiply it and return the new value.
# 5. Otherwise just return the last learning rate

# %%
class StepLRWithWarmup(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, step_size, gamma=0.1, warmup_epochs=3, warmup_lr_init=1e-5, 
                 min_lr=1e-5,
                 last_epoch=-1, verbose=False):
        self.step_size = step_size
        self.gamma = gamma
        self.warmup_epochs = warmup_epochs
        self.warmup_lr_init = warmup_lr_init
        self.min_lr = min_lr
        
        super().__init__(optimizer, last_epoch, verbose)

    def get_lr(self):
        if not self._get_lr_called_within_step:
            warnings.warn("To get the last learning rate computed by the scheduler, "
                          "please use `get_last_lr()`.", UserWarning)
            
        if (self.last_epoch == 0):
            return [self.warmup_lr_init for _ in self.optimizer.param_groups]
        # YOUR CODE
        if self.last_epoch < self.warmup_epochs:
            lrs = [self.warmup_lr_init for _ in self.optimizer.param_groups]
            return [self.warmup_lr_init + (blr - self.warmup_lr_init) * self.last_epoch / self.warmup_epochs 
                   for (lr, blr) in zip(lrs, self.base_lrs)]
            
        elif self.last_epoch == self.warmup_epochs:
            return self.base_lrs
        elif (self.last_epoch - self.warmup_epochs) % self.step_size != 0:
            return [group['lr'] for group in self.optimizer.param_groups]
        else:
            lrs = [group['lr'] for group in self.optimizer.param_groups]
            lrs = [lr * self.gamma if lr * self.gamma >= self.min_lr else lr for lr in lrs]
            return lrs

# %% [markdown]
# Let's check what you have written.

# %%
WARMUP_LR_INIT = 1e-5
WARMUP_EPOCHS = 10
STEP_SIZE = 10
GAMMA = 0.1
MIN_LR = 1e-5
OPT_LR = 1e-3

dummy_net = nn.Sequential(nn.Linear(10,10))
dummy_opt = torch.optim.Adam(dummy_net.parameters(), lr=OPT_LR)

scheduler = StepLRWithWarmup(dummy_opt, step_size=STEP_SIZE, gamma=GAMMA, 
                                      warmup_epochs=WARMUP_EPOCHS, warmup_lr_init=WARMUP_LR_INIT,
                                      min_lr=MIN_LR)

# we need to do at least one optimizer step before calling scheduler.step()
# in order to make pytorch happy
dummy_opt.step()  


learning_rates = []
for i in range(100):
    learning_rates.append(scheduler.get_last_lr())
    scheduler.step()
    
plt.plot(learning_rates)
plt.grid()
plt.title('Learning rates')
    
assert np.isclose(learning_rates[0], WARMUP_LR_INIT), \
    f"LR on the first epoch should be equal to {WARMUP_LR_INIT}, actual value {learning_rates[0]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS], OPT_LR), \
    f"LR after warmup shold be equal to {OPT_LR}, actual value {learning_rates[WARMUP_EPOCHS]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS+STEP_SIZE-1], OPT_LR), \
    f"LR after warmup + (STEP_SIZE-1) steps should be equal to {OPT_LR}, "\
    f"actual value {learning_rates[WARMUP_EPOCHS+STEP_SIZE-1]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS+STEP_SIZE], OPT_LR*GAMMA), \
    f"LR after warmup + (STEP_SIZE) steps shold be equal to {OPT_LR*GAMMA}, " \
    f"actual value {learning_rates[WARMUP_EPOCHS+STEP_SIZE]}"

assert np.isclose(learning_rates[WARMUP_EPOCHS+STEP_SIZE*2-1], OPT_LR*GAMMA), \
    f"LR after warmup + (2*STEP_SIZE-1) steps should be equal to {OPT_LR*GAMMA}, "\
    f"actual value {learning_rates[WARMUP_EPOCHS+STEP_SIZE*2-1]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS+2*STEP_SIZE], OPT_LR*GAMMA**2), \
    f"LR after warmup + (2*STEP_SIZE) steps shold be equal to {OPT_LR*GAMMA**2}, " \
    f"actual value {learning_rates[WARMUP_EPOCHS+2*STEP_SIZE]}"

assert np.isclose(learning_rates[WARMUP_EPOCHS+3*STEP_SIZE], OPT_LR*GAMMA**2), \
    f"LR after warmup + (3*STEP_SIZE) steps shold be equal to {OPT_LR*GAMMA**2}, " \
    f"actual value {learning_rates[WARMUP_EPOCHS+3*STEP_SIZE]}"

for i in range(WARMUP_EPOCHS):
    expected_val = WARMUP_LR_INIT + i*(OPT_LR-WARMUP_LR_INIT) / WARMUP_EPOCHS
    actual_val = learning_rates[i]
    assert np.isclose(actual_val, expected_val), \
        f"LR should linary increase from {WARMUP_LR_INIT} to {OPT_LR} during warmup."\
        f"Expected: {expected_val}, actual: {actual_val}, iteration={i}"
assert all(elem[0] >= MIN_LR for elem in learning_rates)
print("All asserts were passed!")
# Out:
# All asserts were passed!

# %% [markdown]
# ## Task 3. Compact Convolutional Transformer
#
# During seminar you learned the main components of vision transformer: Tokenizer, Transformer encoder, position embeddings. At this point, it's expected that you have solved the ipython notebook from the seminar. If you didn't, then you know what to do before starting the current task)

# %% [markdown]
# Your task is to implement Compact Convolutional Transformer (CCT). It has two main changes comparing to the original ViT that was implemented during seminar. The first one is in tokenizer. Authors of CCT suggested to apply the first convolution with stride=1 allowing transformer to work with input patches that overlaps with each other. Since simple removing of stride increases the spatial resolution of the input tensor, we use MaxPool2d with desired stride in order to reduce the number of tokens.

# %%
class TokenizerCCT(nn.Module):
    def __init__(self,
                 kernel_size=3, stride=1, padding=1,
                 pooling_kernel_size=3, pooling_stride=2, pooling_padding=1,
                 n_input_channels=3,
                 n_output_channels=64,
                 ):
        super().__init__()
        self.tokenizer_layers = nn.Sequential(
                # YOUR CODE
                # it should implement the following sequence of layers:
                # Conv2d(n_input_channels, n_output_channels, kernel_size, stride, padding, bias=False) + 
                #   + ReLU + 
                #   + MaxPool(pooling_kernel_size, pooling_stride, pooling_padding)
                nn.Conv2d(n_input_channels, n_output_channels, kernel_size, stride, padding, bias=False),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=pooling_kernel_size, 
                           stride=pooling_stride, 
                           padding=pooling_padding))

        self.flattener = nn.Flatten(2, 3)  # flat h,w dims into token dim

    def forward(self, x):
        y = self.tokenizer_layers(x)
        y = self.flattener(y)
        y = y.transpose(-2, -1)  # swap token dim and embedding dim
        return y

# %% [markdown]
# The second change is that CCT uses learnable pooling instead of class token for global features extraction. Its formula is similar to attention formula:
# $$y = \text{softmax}(WX^T+b) * X$$
# where $X$ - layer input - matrix of shape [batch_size, n_tokens, n_embedding], $W$, $b$ - learnable parameters, that transform each token embedding vector to 1 element (in fact it's just a linear layer with output_dim=1).

# %%
class SeqPooling(nn.Module):
    def __init__(self, embedding_dim):
        super().__init__()
        self.attention_pool = nn.Linear(embedding_dim, 1)
          
    def forward(self, x):
        # YOUR CODE
        # 1. apply self.attention_pool to x
        w = self.attention_pool(x)
        # 2. take softmax over the first dim (token dim)
        w = F.softmax(w, dim=1)
        # 3. transpose two last dims of w to make its shape be equal to [N, 1, n_tokens]
        w = torch.transpose(w, -1, -2)
        
        # 4. call torch.matmul from 'w' and input tensor 'x'
        y = torch.matmul(w, x)
        
        # 5. now 'y' shape is [N, 1, embedding_dim]. Squeeze the second dim
        y = torch.squeeze(y, dim=1)
        
        return y

# %% [markdown]
# The following three modules were implemented by you during seminar, so you can just copy-paste their implementations.

# %%
def create_mlp(embedding_dim, mlp_size, dropout_rate):
    return nn.Sequential(
        # YOUR CODE: Linear + GELU + Dropout + Linear + Dropout
        nn.Linear(embedding_dim, mlp_size),
        nn.GELU(),
        nn.Dropout(dropout_rate),
        nn.Linear(mlp_size, embedding_dim),
        nn.Dropout(dropout_rate)
    )

# %%
class DropPath(nn.Module):
    def __init__(self, drop_prob=None):
        super(DropPath, self).__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0. or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)  # work with diff dim tensors, not just 2D ConvNets
        # YOUR CODE: generate random tensor, binarize it, cast to x.dtype, multiply x by the mask, 
        # devide the result on keep_prob
        random_tensor = (torch.rand(shape, device=x.device) > self.drop_prob).type(x.dtype)
        output = (x * random_tensor) / keep_prob
        return output

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, embedding_dim, num_heads, mlp_size, dropout=0.1, attention_dropout=0.1,
                 drop_path_rate=0.1):
        super().__init__()
        # YOUR CODE
        self.attention_pre_norm = nn.LayerNorm(embedding_dim)
        self.attention = torch.nn.MultiheadAttention(embed_dim=embedding_dim, 
                                                     num_heads=num_heads, 
                                                     dropout=attention_dropout,
                                                     batch_first=True)
        self.attention_output_dropout = nn.Dropout(dropout)

        self.mlp_pre_norm = nn.LayerNorm(embedding_dim)
        self.mlp = create_mlp(embedding_dim, mlp_size, dropout)
        self.drop_path = DropPath(drop_path_rate) if drop_path_rate > 0 else nn.Identity()

    def forward(self, x):
        # first block
        y = self.attention_pre_norm(x)
        attention = self.attention(y, y, y)[0]
        attention = self.attention_output_dropout(attention)
        x = x + self.drop_path(attention)   # Residual connection
            
        # second block
        y = self.mlp_pre_norm(x)
        y = self.mlp(y)
        x = x + self.drop_path(y)  # Residual connection
        return x

# %% [markdown]
# The final class for the CCT. It looks the same as `VisionTransformer` class in seminar notebook, except the custom tokenizer and pooling. Here we implement a simple version of CCT, whose Tokenizer consist of one convolution of 3x3.

# %%
class CompactConvTransformer3x1(nn.Module):
    def __init__(self,
                 input_height, input_width,
                 n_tokens,
                 n_input_channels,
                 embedding_dim,
                 num_layers,
                 num_heads=4,
                 num_classes=10,
                 mlp_ratio=2,
                 dropout=0.1,
                 attention_dropout=0.1,
                 stochastic_depth=0.1):
        super().__init__()
        
        # 1. Tokenizer
        pooling_stride = 2
        self.tokenizer = TokenizerCCT(kernel_size=3, stride=1, padding=1, 
                                      pooling_kernel_size=3, pooling_stride=pooling_stride, pooling_padding=1,
                                      n_output_channels=embedding_dim)
        n_tokens = input_height // pooling_stride
        
        # 2. Positional embeddings
        self.positional_embeddings = torch.nn.Parameter(
            torch.empty((1, n_tokens*n_tokens, embedding_dim)), requires_grad=True)
        torch.nn.init.trunc_normal_(self.positional_embeddings, std=0.2)
        
        # 3. TransformerEncoder with DropPath
        mlp_size = int(embedding_dim * mlp_ratio)
        layers_drop_path_rate = [x.item() for x in torch.linspace(0, stochastic_depth, num_layers)]
        self.blocks = nn.Sequential(*[
            TransformerEncoder(
                embedding_dim, num_heads, mlp_size, 
                dropout=dropout, attention_dropout=attention_dropout,
                drop_path_rate=layers_drop_path_rate[i]) 
            for i in range(num_layers)])
        
        # 4. normalization before pooling
        self.norm = nn.LayerNorm(embedding_dim)
        
        # 5. sequence pooling
        self.pool = SeqPooling(embedding_dim)

        # 6. layer for the final prediction
        self.fc = nn.Linear(embedding_dim, num_classes)
        
    def forward(self, x):
        # YOUR CODE
        # 1. apply tokenizer to x
        patch_embeddings = self.tokenizer(x)
        
        # 2. add position embeddings
        x = patch_embeddings + self.positional_embeddings

        # 3. apply transformer encoder blocks
        for block in self.blocks:
            x = block(x)
            
        # 4. apply self.norm
        x = self.norm(x)
        
        # 5. apply sequence pooling
        x = self.pool(x)
        
        # 6. final prediction
        x = self.fc(x)
        return x

# %% [markdown]
# ## Final training
#
# If everything was implemented correctly, the following code will give you a model with > 85.5% accuracy (in fact it should be ~87.5%). If you see a smaller number, check your implementation of modules above.

# %%
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

model = CompactConvTransformer3x1(input_height=32, input_width=32, n_tokens=16, n_input_channels=3, 
                                  embedding_dim=128, num_layers=4, num_heads=4, num_classes=10, mlp_ratio=2)
model = model.to(device)
opt = torch.optim.Adam(model.parameters(), weight_decay=1e-4)
scheduler = StepLRWithWarmup(opt, 40, gamma=0.3, warmup_epochs=10)

# %%
import time
num_epochs = 120 # total amount of full passes over training data

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    train_loss = []
    val_accuracy = []
    
    for X_batch, y_batch in train_batch_gen:
        opt.zero_grad()
        # train on batch
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        
        logits = model(X_batch)
        loss = compute_loss(logits, y_batch)
        loss.backward()
        opt.step()
        train_loss.append(loss.data.numpy())
    print (scheduler.get_last_lr())
    scheduler.step()
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        X_batch = X_batch.to(device)
        y_batch = y_batch.numpy()
        logits = model(X_batch).cpu()
        y_pred = logits.max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss)))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy) * 100))
# Out:
# [1e-05]
# Epoch 1 of 120 took 80.401s
#   training loss (in-iteration): 	2.060097
#   validation accuracy: 			32.38 %
# [0.00010899999999999999]
# Epoch 2 of 120 took 81.633s
#   training loss (in-iteration): 	1.716720
#   validation accuracy: 			46.76 %
# [0.000208]
# Epoch 3 of 120 took 81.336s
#   training loss (in-iteration): 	1.485879
#   validation accuracy: 			54.45 %
# [0.00030700000000000004]
# Epoch 4 of 120 took 80.730s
#   training loss (in-iteration): 	1.331916
#   validation accuracy: 			59.12 %
# [0.000406]
# Epoch 5 of 120 took 81.831s
#   training loss (in-iteration): 	1.226917
#   validation accuracy: 			63.93 %
# [0.000505]
# Epoch 6 of 120 took 81.288s
#   training loss (in-iteration): 	1.154137
#   validation accuracy: 			65.06 %
# [0.000604]
# Epoch 7 of 120 took 81.805s
#   training loss (in-iteration): 	1.086865
#   validation accuracy: 			63.91 %
# [0.0007030000000000001]
# Epoch 8 of 120 took 81.447s
#   training loss (in-iteration): 	1.045837
#   validation accuracy: 			67.24 %
# [0.000802]
# Epoch 9 of 120 took 81.757s
#   training loss (in-iteration): 	1.013168
#   validation accuracy: 			68.41 %
# [0.000901]
# Epoch 10 of 120 took 81.951s
#   training loss (in-iteration): 	0.993328
#   validation accuracy: 			67.20 %
# [0.001]
# Epoch 11 of 120 took 81.309s
#   training loss (in-iteration): 	0.968937
#   validation accuracy: 			68.10 %
# [0.001]
# Epoch 12 of 120 took 82.230s
#   training loss (in-iteration): 	0.939768
#   validation accuracy: 			70.13 %
# [0.001]
# Epoch 13 of 120 took 82.553s
#   training loss (in-iteration): 	0.904992
#   validation accuracy: 			73.32 %
# [0.001]
# Epoch 14 of 120 took 81.882s
#   training loss (in-iteration): 	0.873790
#   validation accuracy: 			71.34 %
# [0.001]
# Epoch 15 of 120 took 81.708s
#   training loss (in-iteration): 	0.849269
#   validation accuracy: 			70.70 %
# [0.001]
# Epoch 16 of 120 took 80.996s
#   training loss (in-iteration): 	0.833338
#   validation accuracy: 			73.64 %
# [0.001]
# Epoch 17 of 120 took 81.128s
#   training loss (in-iteration): 	0.809963
#   validation accuracy: 			75.29 %
# [0.001]
# Epoch 18 of 120 took 82.141s
#   training loss (in-iteration): 	0.789599
#   validation accuracy: 			75.48 %
# [0.001]
# Epoch 19 of 120 took 82.143s
#   training loss (in-iteration): 	0.773509
#   validation accuracy: 			75.40 %
# [0.001]
# Epoch 20 of 120 took 82.118s
#   training loss (in-iteration): 	0.754358
#   validation accuracy: 			76.16 %
# [0.001]
# Epoch 21 of 120 took 82.192s
#   training loss (in-iteration): 	0.741321
#   validation accuracy: 			76.43 %
# [0.001]
# Epoch 22 of 120 took 81.498s
#   training loss (in-iteration): 	0.729300
#   validation accuracy: 			75.68 %
# [0.001]
# Epoch 23 of 120 took 81.039s
#   training loss (in-iteration): 	0.712709
#   validation accuracy: 			78.52 %
# [0.001]
# Epoch 24 of 120 took 81.221s
#   training loss (in-iteration): 	0.708943
#   validation accuracy: 			74.03 %
# [0.001]
# Epoch 25 of 120 took 81.101s
#   training loss (in-iteration): 	0.692573
#   validation accuracy: 			78.31 %
# [0.001]
# Epoch 26 of 120 took 82.777s
#   training loss (in-iteration): 	0.679262
#   validation accuracy: 			77.71 %
# [0.001]
# Epoch 27 of 120 took 82.391s
#   training loss (in-iteration): 	0.671707
#   validation accuracy: 			76.86 %
# [0.001]
# Epoch 28 of 120 took 81.887s
#   training loss (in-iteration): 	0.667366
#   validation accuracy: 			78.70 %
# [0.001]
# Epoch 29 of 120 took 81.671s
#   training loss (in-iteration): 	0.651862
#   validation accuracy: 			79.05 %
# [0.001]
# Epoch 30 of 120 took 82.058s
#   training loss (in-iteration): 	0.646410
#   validation accuracy: 			79.01 %
# [0.001]
# Epoch 31 of 120 took 82.309s
#   training loss (in-iteration): 	0.637813
#   validation accuracy: 			80.01 %
# [0.001]
# Epoch 32 of 120 took 82.548s
#   training loss (in-iteration): 	0.630428
#   validation accuracy: 			79.36 %
# [0.001]
# Epoch 33 of 120 took 82.567s
#   training loss (in-iteration): 	0.618647
#   validation accuracy: 			80.16 %
# [0.001]
# Epoch 34 of 120 took 81.727s
#   training loss (in-iteration): 	0.619286
#   validation accuracy: 			80.32 %
# [0.001]
# Epoch 35 of 120 took 81.493s
#   training loss (in-iteration): 	0.609334
#   validation accuracy: 			79.12 %
# [0.001]
# Epoch 36 of 120 took 81.600s
#   training loss (in-iteration): 	0.602163
#   validation accuracy: 			80.17 %
# [0.001]
# Epoch 37 of 120 took 82.242s
#   training loss (in-iteration): 	0.597437
#   validation accuracy: 			80.75 %
# [0.001]
# Epoch 38 of 120 took 82.575s
#   training loss (in-iteration): 	0.591459
#   validation accuracy: 			80.64 %
# [0.001]
# Epoch 39 of 120 took 82.468s
#   training loss (in-iteration): 	0.582651
#   validation accuracy: 			80.43 %
# [0.001]
# Epoch 40 of 120 took 83.153s
#   training loss (in-iteration): 	0.583854
#   validation accuracy: 			80.56 %
# [0.001]
# Epoch 41 of 120 took 81.707s
#   training loss (in-iteration): 	0.575094
#   validation accuracy: 			82.41 %
# [0.001]
# Epoch 42 of 120 took 81.953s
#   training loss (in-iteration): 	0.571045
#   validation accuracy: 			81.35 %
# [0.001]
# Epoch 43 of 120 took 81.404s
#   training loss (in-iteration): 	0.562245
#   validation accuracy: 			81.09 %
# [0.001]
# Epoch 44 of 120 took 82.068s
#   training loss (in-iteration): 	0.561263
#   validation accuracy: 			81.94 %
# [0.001]
# Epoch 45 of 120 took 82.860s
#   training loss (in-iteration): 	0.558443
#   validation accuracy: 			79.38 %
# [0.001]
# Epoch 46 of 120 took 81.486s
#   training loss (in-iteration): 	0.554438
#   validation accuracy: 			82.99 %
# [0.001]
# Epoch 47 of 120 took 81.871s
#   training loss (in-iteration): 	0.547835
#   validation accuracy: 			82.49 %
# [0.001]
# Epoch 48 of 120 took 83.428s
#   training loss (in-iteration): 	0.543364
#   validation accuracy: 			83.17 %
# [0.001]
# Epoch 49 of 120 took 81.798s
#   training loss (in-iteration): 	0.544972
#   validation accuracy: 			82.33 %
# [0.001]
# Epoch 50 of 120 took 82.114s
#   training loss (in-iteration): 	0.534364
#   validation accuracy: 			82.48 %
# [0.0003]
# Epoch 51 of 120 took 81.401s
#   training loss (in-iteration): 	0.427328
#   validation accuracy: 			84.84 %
# [0.0003]
# Epoch 52 of 120 took 81.501s
#   training loss (in-iteration): 	0.405547
#   validation accuracy: 			85.26 %
# [0.0003]
# Epoch 53 of 120 took 82.405s
#   training loss (in-iteration): 	0.393252
#   validation accuracy: 			85.08 %
# [0.0003]
# Epoch 54 of 120 took 82.100s
#   training loss (in-iteration): 	0.389255
#   validation accuracy: 			85.68 %
# [0.0003]
# Epoch 55 of 120 took 82.408s
#   training loss (in-iteration): 	0.380844
#   validation accuracy: 			85.48 %
# [0.0003]
# Epoch 56 of 120 took 81.392s
#   training loss (in-iteration): 	0.373740
#   validation accuracy: 			85.61 %
# [0.0003]
# Epoch 57 of 120 took 81.207s
#   training loss (in-iteration): 	0.368370
#   validation accuracy: 			85.37 %
# [0.0003]
# Epoch 58 of 120 took 79.974s
#   training loss (in-iteration): 	0.368394
#   validation accuracy: 			85.52 %
# [0.0003]
# Epoch 59 of 120 took 82.338s
#   training loss (in-iteration): 	0.360515
#   validation accuracy: 			86.04 %
# [0.0003]
# Epoch 60 of 120 took 82.577s
#   training loss (in-iteration): 	0.359060
#   validation accuracy: 			85.92 %
# [0.0003]
# Epoch 61 of 120 took 82.040s
#   training loss (in-iteration): 	0.352858
#   validation accuracy: 			85.43 %
# [0.0003]
# Epoch 62 of 120 took 82.082s
#   training loss (in-iteration): 	0.350445
#   validation accuracy: 			85.96 %
# [0.0003]
# Epoch 63 of 120 took 82.235s
#   training loss (in-iteration): 	0.349828
#   validation accuracy: 			85.33 %
# [0.0003]
# Epoch 64 of 120 took 81.186s
#   training loss (in-iteration): 	0.346758
#   validation accuracy: 			85.28 %
# [0.0003]
# Epoch 65 of 120 took 82.892s
#   training loss (in-iteration): 	0.340065
#   validation accuracy: 			85.61 %
# [0.0003]
# Epoch 66 of 120 took 82.711s
#   training loss (in-iteration): 	0.338056
#   validation accuracy: 			85.91 %
# [0.0003]
# Epoch 67 of 120 took 82.830s
#   training loss (in-iteration): 	0.339385
#   validation accuracy: 			85.12 %
# [0.0003]
# Epoch 68 of 120 took 81.192s
#   training loss (in-iteration): 	0.337458
#   validation accuracy: 			85.58 %
# [0.0003]
# Epoch 69 of 120 took 81.992s
#   training loss (in-iteration): 	0.330329
#   validation accuracy: 			85.67 %
# [0.0003]
# Epoch 70 of 120 took 80.320s
#   training loss (in-iteration): 	0.325924
#   validation accuracy: 			86.14 %
# [0.0003]
# Epoch 71 of 120 took 82.670s
#   training loss (in-iteration): 	0.330288
#   validation accuracy: 			86.12 %
# [0.0003]
# Epoch 72 of 120 took 82.415s
#   training loss (in-iteration): 	0.325094
#   validation accuracy: 			86.15 %
# [0.0003]
# Epoch 73 of 120 took 82.539s
#   training loss (in-iteration): 	0.322142
#   validation accuracy: 			86.23 %
# [0.0003]
# Epoch 74 of 120 took 82.423s
#   training loss (in-iteration): 	0.317245
#   validation accuracy: 			85.81 %
# [0.0003]
# Epoch 75 of 120 took 81.564s
#   training loss (in-iteration): 	0.320709
#   validation accuracy: 			85.83 %
# [0.0003]
# Epoch 76 of 120 took 80.603s
#   training loss (in-iteration): 	0.321469
#   validation accuracy: 			85.26 %
# [0.0003]
# Epoch 77 of 120 took 82.416s
#   training loss (in-iteration): 	0.313443
#   validation accuracy: 			85.30 %
# [0.0003]
# Epoch 78 of 120 took 81.338s
#   training loss (in-iteration): 	0.311941
#   validation accuracy: 			85.91 %
# [0.0003]
# Epoch 79 of 120 took 82.615s
#   training loss (in-iteration): 	0.312980
#   validation accuracy: 			85.99 %
# [0.0003]
# Epoch 80 of 120 took 81.285s
#   training loss (in-iteration): 	0.308389
#   validation accuracy: 			85.79 %
# [0.0003]
# Epoch 81 of 120 took 81.171s
#   training loss (in-iteration): 	0.307054
#   validation accuracy: 			85.56 %
# [0.0003]
# Epoch 82 of 120 took 82.197s
#   training loss (in-iteration): 	0.306719
#   validation accuracy: 			86.23 %
# [0.0003]
# Epoch 83 of 120 took 82.512s
#   training loss (in-iteration): 	0.308129
#   validation accuracy: 			86.01 %
# [0.0003]
# Epoch 84 of 120 took 81.527s
#   training loss (in-iteration): 	0.300554
#   validation accuracy: 			86.34 %
# [0.0003]
# Epoch 85 of 120 took 82.144s
#   training loss (in-iteration): 	0.300584
#   validation accuracy: 			86.39 %
# [0.0003]
# Epoch 86 of 120 took 81.357s
#   training loss (in-iteration): 	0.301363
#   validation accuracy: 			85.93 %
# [0.0003]
# Epoch 87 of 120 took 80.802s
#   training loss (in-iteration): 	0.295520
#   validation accuracy: 			86.27 %
# [0.0003]
# Epoch 88 of 120 took 80.713s
#   training loss (in-iteration): 	0.296343
#   validation accuracy: 			85.81 %
# [0.0003]
# Epoch 89 of 120 took 81.955s
#   training loss (in-iteration): 	0.294755
#   validation accuracy: 			85.59 %
# [0.0003]
# Epoch 90 of 120 took 80.026s
#   training loss (in-iteration): 	0.292857
#   validation accuracy: 			85.60 %
# [8.999999999999999e-05]
# Epoch 91 of 120 took 81.964s
#   training loss (in-iteration): 	0.245095
#   validation accuracy: 			86.84 %
# [8.999999999999999e-05]
# Epoch 92 of 120 took 82.360s
#   training loss (in-iteration): 	0.234558
#   validation accuracy: 			87.06 %
# [8.999999999999999e-05]
# Epoch 93 of 120 took 83.384s
#   training loss (in-iteration): 	0.233693
#   validation accuracy: 			87.08 %
# [8.999999999999999e-05]
# Epoch 94 of 120 took 81.712s
#   training loss (in-iteration): 	0.229536
#   validation accuracy: 			87.01 %
# [8.999999999999999e-05]
# Epoch 95 of 120 took 81.934s
#   training loss (in-iteration): 	0.222254
#   validation accuracy: 			86.99 %
# [8.999999999999999e-05]
# Epoch 96 of 120 took 81.235s
#   training loss (in-iteration): 	0.222779
#   validation accuracy: 			87.10 %
# [8.999999999999999e-05]
# Epoch 97 of 120 took 81.134s
#   training loss (in-iteration): 	0.220880
#   validation accuracy: 			86.97 %
# [8.999999999999999e-05]
# Epoch 98 of 120 took 80.641s
#   training loss (in-iteration): 	0.221657
#   validation accuracy: 			87.03 %
# [8.999999999999999e-05]
# Epoch 99 of 120 took 81.485s
#   training loss (in-iteration): 	0.214346
#   validation accuracy: 			87.02 %
# [8.999999999999999e-05]
# Epoch 100 of 120 took 81.580s
#   training loss (in-iteration): 	0.215968
#   validation accuracy: 			87.21 %
# [8.999999999999999e-05]
# Epoch 101 of 120 took 82.602s
#   training loss (in-iteration): 	0.215501
#   validation accuracy: 			86.91 %
# [8.999999999999999e-05]
# Epoch 102 of 120 took 82.029s
#   training loss (in-iteration): 	0.218647
#   validation accuracy: 			86.97 %
# [8.999999999999999e-05]
# Epoch 103 of 120 took 81.911s
#   training loss (in-iteration): 	0.211299
#   validation accuracy: 			86.97 %
# [8.999999999999999e-05]
# Epoch 104 of 120 took 81.820s
#   training loss (in-iteration): 	0.215167
#   validation accuracy: 			86.76 %
# [8.999999999999999e-05]
# Epoch 105 of 120 took 81.642s
#   training loss (in-iteration): 	0.210677
#   validation accuracy: 			86.89 %
# [8.999999999999999e-05]
# Epoch 106 of 120 took 81.441s
#   training loss (in-iteration): 	0.207322
#   validation accuracy: 			87.01 %
# [8.999999999999999e-05]
# Epoch 107 of 120 took 82.828s
#   training loss (in-iteration): 	0.207618
#   validation accuracy: 			87.08 %
# [8.999999999999999e-05]
# Epoch 108 of 120 took 81.213s
#   training loss (in-iteration): 	0.209305
#   validation accuracy: 			86.80 %
# [8.999999999999999e-05]
# Epoch 109 of 120 took 81.406s
#   training loss (in-iteration): 	0.208533
#   validation accuracy: 			86.78 %
# [8.999999999999999e-05]
# Epoch 110 of 120 took 81.513s
#   training loss (in-iteration): 	0.203533
#   validation accuracy: 			86.94 %
# [8.999999999999999e-05]
# Epoch 111 of 120 took 82.581s
#   training loss (in-iteration): 	0.201870
#   validation accuracy: 			86.60 %
# [8.999999999999999e-05]
# Epoch 112 of 120 took 82.369s
#   training loss (in-iteration): 	0.202091
#   validation accuracy: 			86.97 %
# [8.999999999999999e-05]
# Epoch 113 of 120 took 81.673s
#   training loss (in-iteration): 	0.202309
#   validation accuracy: 			86.95 %
# [8.999999999999999e-05]
# Epoch 114 of 120 took 81.291s
#   training loss (in-iteration): 	0.201860
#   validation accuracy: 			86.93 %
# [8.999999999999999e-05]
# Epoch 115 of 120 took 83.220s
#   training loss (in-iteration): 	0.201143
#   validation accuracy: 			87.07 %
# [8.999999999999999e-05]
# Epoch 116 of 120 took 81.752s
#   training loss (in-iteration): 	0.198410
#   validation accuracy: 			87.18 %
# [8.999999999999999e-05]
# Epoch 117 of 120 took 80.840s
#   training loss (in-iteration): 	0.200189
#   validation accuracy: 			86.96 %
# [8.999999999999999e-05]
# Epoch 118 of 120 took 81.766s
#   training loss (in-iteration): 	0.195953
#   validation accuracy: 			86.80 %
# [8.999999999999999e-05]
# Epoch 119 of 120 took 81.848s
#   training loss (in-iteration): 	0.196649
#   validation accuracy: 			86.93 %
# [8.999999999999999e-05]
# Epoch 120 of 120 took 82.067s
#   training loss (in-iteration): 	0.195450
#   validation accuracy: 			87.06 %
